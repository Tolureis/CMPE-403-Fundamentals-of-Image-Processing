# %% [markdown]
# <a href="https://colab.research.google.com/github/Tolureis/CMPE-403-Fundamentals-of-Image-Processing/blob/main/Opencv_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Read-Show-Save image

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")

if img is not None:
    cv2_imshow(img)
    cv2.imwrite("copy.jpg", img)
else:
    print("Error: image not found.")
# Out:
# <PIL.Image.Image image mode=RGB size=181x278>

# %% [markdown]
# # 2) Color Spaces + GrayScale

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")

if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

    print("Gray Scale:")
    cv2_imshow(gray)
    print("HSV:")
    cv2_imshow(hsv)
else:
    print("Error: image not found.")
# Out:
# Gray Scale:
# <PIL.Image.Image image mode=L size=181x278>
# HSV:
# <PIL.Image.Image image mode=RGB size=181x278>

# %% [markdown]
# # 3) Blur

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")

if img is not None:
    gaussian = cv2.GaussianBlur(img, (7,7), 0)
    median = cv2.medianBlur(img, 5)

    print("Gaussian Blur:")
    cv2_imshow(gaussian)
    print("Median Blur:")
    cv2_imshow(median)
else:
    print("Error: image not found.")
# Out:
# Gaussian Blur:
# <PIL.Image.Image image mode=RGB size=181x278>
# Median Blur:
# <PIL.Image.Image image mode=RGB size=181x278>

# %% [markdown]
# # 4) Edge Detection (Canny)

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")
if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)

    print("Canny Edge Detection:")
    cv2_imshow(edges)
else:
    pprint("Error: image not found.")
# Out:
# Canny Edge Detection:
# <PIL.Image.Image image mode=L size=181x278>

# %% [markdown]
# # 5) Threshold + Binary Mask

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")
if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 120, 255, cv2.THRESH_BINARY)

    print("Binary Threshold:")
    cv2_imshow(binary)
else:
    print("Error: image not found.")
# Out:
# Binary Threshold:
# <PIL.Image.Image image mode=L size=181x278>

# %% [markdown]
# # 6) Adaptive Threshold

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")
if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    adaptive = cv2.adaptiveThreshold(
        gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2
    )

    print("Adaptive Threshold:")
    cv2_imshow(adaptive)
else:
    print("Error: image not found.")
# Out:
# Adaptive Threshold:
# <PIL.Image.Image image mode=L size=181x278>

# %% [markdown]
# # 7) Morphological Operations

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg", 0)
if img is not None:
    _, binary = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY)
    kernel = np.ones((5,5), np.uint8)

    opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

    print("Morphological Opening:")
    cv2_imshow(opening)
else:
    print("Error: image not found.")
# Out:
# Morphological Opening:
# <PIL.Image.Image image mode=L size=181x278>

# %% [markdown]
# # 8) Contour Detection

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")
if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 120, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for c in contours:
        cv2.drawContours(img, [c], -1, (0,255,0), 2)

    print("Contours:")
    cv2_imshow(img)
else:
    print("Error: image not found.")
# Out:
# Contours:
# <PIL.Image.Image image mode=RGB size=181x278>
