# %% [markdown]
# <a href="https://colab.research.google.com/github/Tolureis/CMPE-403-Fundamentals-of-Image-Processing/blob/main/Gaussian_Median_Blur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
# Write the path of your external image file here
image_path = '/content/shrek.jpg'

if not os.path.exists(image_path):
    raise FileNotFoundError(f'Image file not found: {image_path}')

image_bgr = cv2.imread(image_path)

if image_bgr is None:
    raise ValueError('OpenCV could not read the image. Check the file path and file format.')

image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

print('Image loaded successfully.')
print('Shape:', image_rgb.shape)
# Out:
# Image loaded successfully.
# Shape: (278, 181, 3)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
gaussian_blur = cv2.GaussianBlur(image_rgb, (9, 9), 0)
median_blur = cv2.medianBlur(image_rgb, 9)

# %%
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(gaussian_blur)
plt.title('Gaussian Blur')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(median_blur)
plt.title('Median Blur')
plt.axis('off')

plt.tight_layout()
plt.show()
